# %%
import pandas as pd
# Out:
# StatementMeta(, e944a953-ce80-47a8-8f39-0d52627ebf57, 3, Finished, Available, Finished)

# %%
# Create sample data
data = [
    (1, 2, "Excellent build quality, love it!", 5, "2025-04-05"),
    (2, 5, "Good value for money.", 4, "2025-04-12"),
    (3, 7, "Works as expected, no complaints.", 4, "2025-04-15"),
    (4, 1, "Not satisfied with the durability.", 2, "2025-04-09"),
    (5, 8, "Amazing features at this price!", 5, "2025-04-18"),
    (6, 9, "Packaging was poor but product ok.", 3, "2025-04-02"),
    (7, 3, "Highly recommend this item!", 5, "2025-04-10"),
    (8, 10, "Battery life could be better.", 3, "2025-04-14"),
    (9, 4, "Exactly as described, happy!", 4, "2025-04-03"),
    (10, 6, "Not worth the price.", 2, "2025-04-01"),
    (11, 1, "Product met expectations.", 4, "2025-04-06"),
    (12, 7, "Fantastic quality, very satisfied.", 5, "2025-04-16"),
    (13, 2, "Defective unit received.", 1, "2025-04-04"),
    (14, 5, "Customer service was very helpful.", 5, "2025-04-11"),
    (15, 8, "Average performance.", 3, "2025-04-17"),
    (16, 3, "Super easy to use.", 5, "2025-04-07"),
    (17, 6, "Color slightly different than shown.", 3, "2025-04-13"),
    (18, 9, "Love the design and comfort.", 5, "2025-04-08"),
    (19, 10, "Item stopped working after a week.", 1, "2025-04-20"),
    (20, 4, "Good quality for the price.", 4, "2025-04-19")
]
# Out:
# StatementMeta(, e944a953-ce80-47a8-8f39-0d52627ebf57, 4, Finished, Available, Finished)

# %%
df = pd.DataFrame(data, columns=["ReviewID", "ProductID", "ReviewText", "Rating", "ReviewDate"])
# Out:
# StatementMeta(, e944a953-ce80-47a8-8f39-0d52627ebf57, 5, Finished, Available, Finished)

# %%
# Save the DataFrame to the default Lakehouse Files location
output_path = '/lakehouse/default/Files/product_reviews.parquet'
df.to_parquet(output_path, index=False)
# Out:
# StatementMeta(, e944a953-ce80-47a8-8f39-0d52627ebf57, 6, Finished, Available, Finished)
